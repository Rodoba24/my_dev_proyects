# %% [markdown]
# ## Monte Carlo - Forecasting Stock Prices - Part III

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Forecasting Future Stock Prices – continued:

# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
from scipy.stats import norm


data = pd.read_csv('Dataset\MSFT_2000.csv', index_col = 'Date')

log_returns = np.log(1 + data.pct_change())
u = log_returns.mean()
var = log_returns.var()
drift = u - (0.5 * var)
stdev = log_returns.std()

drift.values
stdev.values

t_intervals = 250
iterations = 10

daily_returns = np.exp(drift.values + stdev.values * norm.ppf(np.random.rand(t_intervals, iterations)))

# %% [markdown]
# ***

# %% [markdown]
# Create a variable S0 equal to the last adjusted closing price of Microsoft. Use the “iloc” method.

# %%
S0 = data.iloc[-1]

# %% [markdown]
# Create a variable price_list with the same dimension as the daily_returns matrix.

# %%
price_list = np.zeros_like(daily_returns)

# %% [markdown]
# Set the values on the first row of the price_list array equal to S0.

# %%
price_list[0] = S0

# %% [markdown]
# Create a loop in the range (1, t_intervals) that reassigns to the price in time t the product of the price in day (t-1) with the value of the daily returns in t.

# %%
for t in range(1, t_intervals):
    price_list[t] = price_list[t - 1] * daily_returns[t]

# %% [markdown]
# Finally, plot the obtained price list data.

# %%
plt.Figure(figsize=(10,6))
plt.plot(price_list)
# Out:
# [<matplotlib.lines.Line2D at 0x2522613ac10>,
#  <matplotlib.lines.Line2D at 0x2522b75bc50>,
#  <matplotlib.lines.Line2D at 0x2522b75bd90>,
#  <matplotlib.lines.Line2D at 0x2522b75bed0>,
#  <matplotlib.lines.Line2D at 0x2522b798050>,
#  <matplotlib.lines.Line2D at 0x2522b798190>,
#  <matplotlib.lines.Line2D at 0x2522b7982d0>,
#  <matplotlib.lines.Line2D at 0x2522b798410>,
#  <matplotlib.lines.Line2D at 0x2522b798550>,
#  <matplotlib.lines.Line2D at 0x2522b798690>]

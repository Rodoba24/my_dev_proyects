# %% [markdown]
# ## Calculating the Return of a Portfolio of Securities

# %% [markdown]
# Load the data for a portfolio composed of 5 stocks - British Petroleum, Ford, Exxon, Lincoln, and Apple *(5_stocks_2000_2017.csv)*.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

portfolio = pd.read_csv('Dataset/5_stocks_2000_2017.csv', index_col = 'Date')
portfolio
# Out:
#                    BP          F        XOM        LNC        AAPL
# Date
# 1999-12-31  26.942526  17.911160  25.595554  27.138775    3.291592
# 2000-01-03  26.715410  17.596191  24.880707  26.502689    3.583733
# 2000-01-04  26.573452  17.008251  24.404148  25.739405    3.281587
# 2000-01-05  27.481936  17.071245  25.734549  24.848928    3.329610
# 2000-01-06  27.538712  17.092241  27.064951  25.303717    3.041471
# ...               ...        ...        ...        ...         ...
# 2017-12-06  39.580002  12.380000  82.279999  76.500000  169.009995
# 2017-12-07  39.310001  12.530000  82.550003  77.589996  169.320007
# 2017-12-08  39.639999  12.610000  82.660004  78.540001  169.369995
# 2017-12-11  39.930000  12.580000  83.029999  77.169998  172.669998
# 2017-12-12  40.709999  12.524200  83.313904  77.559998  172.059998
#
# [4517 rows x 5 columns]

# %% [markdown]
# ### Normalization to 100:
#
# $$
# \frac {P_t}{P_0} * 100
# $$

# %% [markdown]
# Normalize to a hundred and plot the data on a graph (you can apply the .loc() or the .iloc() method).

# %%
norm_100 = (portfolio / portfolio.iloc[0] * 100)

# %%
norm_100.plot(figsize=(15,6))
plt.show()

# %% [markdown]
# How would you interpret the behavior of the stocks? Just by looking at the chart, would you be able to create a portfolio that provides a solid return on investment?

# %% [markdown]
# *****

# %% [markdown]
# ### Calculating the Return of a Portfolio of Securities

# %% [markdown]
# Obtain the simple return of the securities in the portfolio and store the results in a new table.

# %%
simp_return = (portfolio / portfolio.shift(-1)) -1
simp_return.head()
# Out:
#                   BP         F       XOM       LNC      AAPL
# Date
# 1999-12-31  0.008501  0.017900  0.028731  0.024001 -0.081519
# 2000-01-03  0.005342  0.034568  0.019528  0.029654  0.092073
# 2000-01-04 -0.033057 -0.003690 -0.051697  0.035836 -0.014423
# 2000-01-05 -0.002062 -0.001228 -0.049156 -0.017973  0.094737
# 2000-01-06  0.018908 -0.068650  0.002943 -0.024711 -0.045226

# %% [markdown]
# First, assume you would like to create an equally-weighted portfolio. Create the array, naming it “weights”.

# %%
weights = np.array([0.50, 0.50, 0.50, 0.50, 0.50])

# %% [markdown]
# Obtain the annual returns of each of the stocks and then calculate the dot product of these returns and the weights.

# %%
annual_return = simp_return.mean() * 250
annual_return
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 annual_return = simp_return.mean() * 250
#       2 annual_return
#
# NameError: name 'simp_return' is not defined

# %%
dot_prod = np.dot(annual_return, weights)

# %% [markdown]
# Transform the result into a percentage form.

# %%
print (str(round(dot_prod,4) * 100) + '%')
# Out:
# 2.78%

# %% [markdown]
# Is the return of this portfolio satisfactory?

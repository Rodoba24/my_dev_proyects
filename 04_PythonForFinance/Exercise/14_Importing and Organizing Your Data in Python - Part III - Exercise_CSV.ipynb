# %% [markdown]
# ## Importing and Organizing Your Data in Python - Part III

# %% [markdown]
# Save the data obtained in the previous exercise as a csv file. Then, save it in an excel format. <br />
# Do you remember which library can help you do that? Don’t forget to import it first!

# %%
# !pip install alpaca-trade-api
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for PyYAML: filename=pyyaml-6.0.1-cp313-cp313-win_amd64.whl size=45473 sha256=f8223c04139b988fb9c8dc16e7e0ea6c0cca8aa7a0360589885ce647cc678b6f
#   Stored in directory: c:\users\roly_\appdata\local\pip\cache\wheels\9c\9e\34\1e1548811b63a9d001469f21797e8b7d5c216d8eb928e7d6ad
# ...
#   Created wheel for websockets: filename=websockets-10.4-cp313-cp313-win_amd64.whl size=95034 sha256=3fa5d6dd0aea7930a49106299ebb9a39b45d38929abeadae3b05ee608098808b
# ...

# %%
import alpaca_trade_api as alpaca

api = alpaca.REST('PKSVKIO35NZMZK00L2Z3', 'ifYF17huHaOsPFqbfkrPGbI9VMxPMHq36RZXJ9np', 'https://paper-api.alpaca.markets')

# %%
import pandas as pd

# %%
tickers = ['AAPL', 'MSFT', 'XOM', 'BP']
new_data = pd.DataFrame()
for t in tickers:
   new_data[t]= api.get_bars(t, "1Day", start='2024-06-01', end='2025-06-30').df['close']

# %%
new_data.to_csv('new_data_0.csv')

# %%
new_data.to_excel('new_data_2.xlsx')

# %%
# Out:
# Mounted at /content/drive

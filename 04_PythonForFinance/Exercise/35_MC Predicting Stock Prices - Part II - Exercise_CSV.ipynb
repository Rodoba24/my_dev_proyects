# %% [markdown]
# ## Monte Carlo - Forecasting Stock Prices - Part II

# %% [markdown]
# *Suggested Answers follow (usually there are multiple ways to solve a problem in Python).*

# %% [markdown]
# Forecasting Future Stock Prices – continued:

# %%
import numpy as np  
import pandas as pd   
import matplotlib.pyplot as plt  
from scipy.stats import norm

data = pd.read_csv('Dataset\MSFT_2000.csv', index_col = 'Date')

log_returns = np.log(1 + data.pct_change())
u = log_returns.mean()
var = log_returns.var()
drift = u - (0.5 * var)
stdev = log_returns.std()

# %% [markdown]
# ******

# %% [markdown]
# Use “.values” to transform the *drift* and the *stdev* objects into arrays.

# %%
drift_val = drift.values
stdev_val = stdev.values

# %% [markdown]
# Forecast future stock prices for every trading day a year ahead. So, assign 250 to “t_intervals”. <br />
# Let’s examine 10 possible outcomes. Bind “iterations” to the value of 10.

# %%
t_intervals = 250
iterations = 10

# %% [markdown]
# Use the formula we have provided and calculate daily returns.

# %% [markdown]
# $$
# daily\_returns = exp({drift} + {stdev} * z),
# $$
# <br \>
# $$
# where\  z = norm.ppf(np.random.rand(t\_intervals, iterations)
# $$

# %%
daily_returns = np.exp(drift_val + stdev_val * norm.ppf(np.random.rand(t_intervals, iterations)))
daily_returns
# Out:
# array([[1.02158709, 1.03161215, 1.01955278, ..., 0.99134346, 0.96981903,
#         1.02346692],
#        [0.98292715, 1.00247086, 1.03620306, ..., 1.03874513, 1.01431182,
#         0.97183495],
#        [1.02296594, 0.98134121, 0.98676433, ..., 1.02198293, 1.01521056,
#         1.00067569],
#        ...,
#        [1.00880872, 0.98991666, 1.01481324, ..., 1.00194448, 1.03565638,
#         0.98046953],
#        [1.00021753, 1.00216687, 1.01938186, ..., 1.00375566, 1.0017128 ,
#         1.02944878],
#        [1.0025594 , 0.98247051, 0.99643743, ..., 1.01216988, 1.01337253,
#         1.00676085]])
